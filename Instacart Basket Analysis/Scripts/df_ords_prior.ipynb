# %% [markdown]
# # Importing libraries

# %%
#Importing libraries 
import pandas as pd 
import numpy as np
import os 

path = r'C:\Users\ANITA BOADU\Achievement 4'

#Import df_ords_prior as 
df_ords_prior=pd.read_csv(os.path.join(path,'Data','Prepared Data','orders_products_prior.csv'),index_col=False)

#Import df_ords as 
df
