# %% [markdown]
# #### step4

# %% [markdown]
# # Importing liabaries

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Python Data Type

# %% [markdown]
# ### Step7

# %%
x=50

# %%
print(x)
# Out:
# 50

# %%
type(x)
# Out:
# int

# %%
y=50

# %%
x+y
# Out:
# 100

# %%
type(x+y)
# Out:
# int

# %%
print(x+y)
# Out:
# 100.0

# %% [markdown]
# ### in this case we added two variables 'x' and 'y' with each value of 50 where x+y add up to 100

# %%
x=75

# %%
type(x)
# Out:
# int

# %%
y=25.0

# %%
type(y)
# Out:
# float

# %%
x+y
# Out:
# 100.0

# %%
print(x+y)
# Out:
# 100.0

# %% [markdown]
# ### Here we added an variable 'x' with a value of 75 as an integer to a float with variable 'y' with a value of 25.0 to make a 100

# %%
x=200

# %%
type(x)
# Out:
# int

# %%
y=2.0

# %%
type(y)
# Out:
# float

# %%
x/y
# Out:
# 100.0

# %%
print(x/y)
# Out:
# 100.0

# %% [markdown]
# #### Here we divided the integer with value 200 by the float with value 2.0 to give us 100

# %% [markdown]
# #### Step 8

# %%
x=76.00

# %%
type(x)
# Out:
# float

# %%
y=3.40

# %%
type(y)
# Out:
# float

# %%
x/y
# Out:
# 22.35294117647059

# %%
print(x/y)
# Out:
# 22.35294117647059

# %%
a=120.00

# %%
type(a)
# Out:
# float

# %%
b=20.00

# %%
type(b)
# Out:
# float

# %%
a/b
# Out:
# 6.0

# %%
print(a/b)
# Out:
# 6.0

# %%
type(a/b)
# Out:
# float

# %% [markdown]
# ##### Step 9 and 10

# %%
a='Welcome, '

# %%
b='Kweku Minta'

# %%
a+b
# Out:
# 'Welcome, Kweku Minta'

# %%
type(a+b)
# Out:
# str

# %%
print(a+b)
# Out:
# Welcome, Kweku Minta

# %% [markdown]
# ###### Bonus Task

# %%
r='love'

# %%
r*100
# Out:
# '...'
